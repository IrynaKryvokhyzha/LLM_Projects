# %% [markdown]
# Job Analyzer AI
#
# Goal:
# A user pastes a job description (or a URL to one), and this app:
#
# -Extracts skills and requirements
#
# -Tells them what they match / lack
#
# -Suggests what to learn
#
# -Generates tailored resume bullets or a cover letter

# %%
# imports
# If these fail, please check you're running from an 'activated' environment with (llms) in the command prompt

import os
import requests
import json
from typing import List
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
# Initialize and constants

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
    
MODEL = 'gpt-4o-mini'
openai = OpenAI()
# Out:
# API key looks good so far

# %%
# A class to represent a Webpage

# Some websites need you to use proper headers when fetching them:
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:
    """
    A utility class to represent a Website that we have scraped, now with links
    """

    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=headers)
        self.body = response.content
        soup = BeautifulSoup(self.body, 'html.parser')

        self.title = soup.title.string if soup.title else "No title found"
        if soup.body:
            for irrelevant in soup.body(["script", "style", "img", "input","nav", "footer", "form", "aside"]):
                irrelevant.decompose()
            self.text = soup.body.get_text(separator="\n", strip=True)
        else:
            self.text = ""
        links = [link.get('href') for link in soup.find_all('a')]
        self.links = [link for link in links if link]

   # # Remove unwanted tags
   #      for tag in soup(["script", "style", "img", "nav", "footer", "form", "aside"]):
   #          tag.decompose()
        
   #      # Try to extract from main or article tag, else fallback to body
   #      main_content = soup.find("main") or soup.find("article") or soup.body
   #      if main_content:
   #          self.text = main_content.get_text(separator="\n", strip=True)
   #      else:
   #          self.text = ""
    def get_contents(self):
        return f"Job Page URL:\n{self.url}\nJob Description:\n{self.text}\n\n"

# %%
job_site = Website("https://www.linkedin.com/jobs/view/4193069481/?alternateChannel=search&refId=lafWDnnnJyIYHU1x4F2jkQ%3D%3D&trackingId=HkuAt27ZU%2B1wJkSdFDI5eQ%3D%3D")
print(job_site.text)
# Out:
# Skip to main content
# Frontend Developer
# Voltora Tech
# United States
# Apply
# Security verification
# Frontend Developer
# Voltora Tech
# United States
# 11 hours ago
# Over 200 applicants
# See who Voltora Tech has hired for this role
# Apply
# Security verification
# Save
# Report this job
# Use AI to assess how you fit
# Get AI-powered advice on this job and more exclusive features.
# Am I a good fit for this job?
# Tailor my resume
# Sign in to access AI-powered advices
# Sign in
# Welcome back
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Sign in to evaluate your skills
# Sign in
# Welcome back
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Sign in to tailor your resume
# Sign in
# Welcome back
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# This is a remote position.
# We are seeking a talented and passionate Front-end Developer to join our growing team. You will be responsible for building and maintaining user-facing applications that are both functional and visually appealing. You will collaborate closely with designers, back-end developers, and product managers to deliver exceptional user experiences. If you are a problem-solver with a strong understanding of modern front-end technologies and a desire to create impactful web applications, we want to hear from you.
# Responsibilities:
# Develop and maintain responsive and user-friendly web applications using modern front-end technologies.
# Translate design mock-ups and wire-frames into high-quality code.
# Collaborate with designers to ensure seamless integration of visual elements and user experience.
# Work closely with back-end developers to integrate APIs and ensure data flow.
# Write clean, maintainable, and well-documented code.
# Participate in code reviews and contribute to improving code quality.
# Optimize applications for maximum speed and scalability.
# Troubleshoot and debug front-end issues.
# Stay up-to-date with the latest front-end technologies and best practices.
# Contribute to the development of front-end architecture and standards.
# Implement and maintain unit and integration tests.
# Participate in agile development processes, including sprint planning, daily stand-ups, and retrospectives.
# Salary:  $70k-$90k
# Show more
# Show less
# Seniority level
# Entry level
# Employment type
# Full-time
# Job function
# Engineering and Information Technology
# Industries
# Technology, Information and Internet
# Referrals increase your chances of interviewing at Voltora Tech by 2x
# See who you know
# Get notified when a new job is posted.
# Set alert
# Sign in to set job alerts for “Frontend Developer” roles.
# Sign in
# Welcome back
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Similar jobs
# Frontend Developer
# Frontend Developer
# Adapty.io
# United States
# 3 weeks ago
# Frontend Engineer
# Frontend Engineer
# Ritual
# New York, NY
# 2 months ago
# Frontend Engineer (Remote)
# Frontend Engineer (Remote)
# Alma
# San Francisco Bay Area
# $3,000.00
#             -
#             $7,000.00
# 3 weeks ago
# Front-End Software Engineer
# Front-End Software Engineer
# Candid
# New York, NY
# 3 days ago
# Front End Developer
# Front End Developer
# Beshenich Muir & Associates
# United States
# 2 weeks ago
# Frontend Engineer (E-Commerce), Data and System
# Frontend Engineer (E-Commerce), Data and System
# Pendulum Therapeutics
# United States
# 1 day ago
# Web Front-End Developer
# Web Front-End Developer
# Lenovo
# Morrisville, NC
# 9 hours ago
# Front End Developer
# Front End Developer
# Acoustic
# United States
# 2 weeks ago
# Frontend Engineer
# Frontend Engineer
# Ideogram
# New York, NY
# 1 day ago
# Software Engineer - Frontend
# Software Engineer - Frontend
# Ever
# San Francisco, CA
# 9 months ago
# Front End Software Engineer
# Front End Software Engineer
# Ollie
# United States
# 3 weeks ago
# Frontend Developer
# Frontend Developer
# The Virtus Solution
# Sandy Springs, GA
# 1 month ago
# Front-End Developer
# Front-End Developer
# United Talent Agency
# Nashville, TN
# $130,000.00
#             -
#             $150,000.00
# 6 days ago
# Frontend Developer - Remote
# Frontend Developer - Remote
# Saga.xyz
# Los Altos, CA
# 1 week ago
# Front-End Developer
# Front-End Developer
# United Talent Agency
# United States
# $130,000.00
#             -
#             $150,000.00
# 2 weeks ago
# Frontend Developer
# Frontend Developer
# Excalibur Works
# United States
# 1 day ago
# Frontend Developer
# Frontend Developer
# InterEx Group
# United States
# 3 weeks ago
# Frontend Engineer
# Frontend Engineer
# Avail
# United States
# 3 months ago
# Front-End Developer
# Front-End Developer
# United Talent Agency
# Los Angeles, CA
# $130,000.00
#             -
#             $150,000.00
# 1 week ago
# Frontend Engineer Internship
# Frontend Engineer Internship
# Coalition, Inc.
# United States
# 6 days ago
# Front-End Developer
# Front-End Developer
# United Talent Agency
# Atlanta, GA
# $130,000.00
#             -
#             $150,000.00
# 2 weeks ago
# Software Engineer, Frontend
# Software Engineer, Frontend
# Wealthfront
# New York, NY
# $140,000.00
#             -
#             $185,000.00
# 1 week ago
# Front-End Developer
# Front-End Developer
# United Talent Agency
# New York, NY
# $130,000.00
#             -
#             $150,000.00
# 2 weeks ago
# [Full Remote] Junior Web Developer
# [Full Remote] Junior Web Developer
# Joinrs US
# United States
# 1 day ago
# Software Engineer, Frontend
# Software Engineer, Frontend
# Wealthfront
# Palo Alto, CA
# $140,000.00
#             -
#             $185,000.00
# 2 weeks ago
# Frontend Developer
# Frontend Developer
# Donyati
# United States
# 1 day ago
# Front End Developer
# Front End Developer
# Eden
# Denver, CO
# 21 hours ago
# Show more jobs like this
# Show fewer jobs like this
# People also viewed
# Frontend Developer (FunnelFox)
# Frontend Developer (FunnelFox)
# Adapty.io
# United States
# 3 weeks ago
# Frontend Developer
# Frontend Developer
# Confirma Tech
# Virginia, United States
# 4 days ago
# Frontend Engineer
# Frontend Engineer
# Cypris
# New York, NY
# 3 weeks ago
# Front-end Software Engineer (Medicare)
# Front-end Software Engineer (Medicare)
# RVO Health
# Minneapolis, MN
# 1 day ago
# Frontend Developer
# Frontend Developer
# DataAnnotation
# Columbus, Ohio Metropolitan Area
# 1 week ago
# Frontend Developer
# Frontend Developer
# Prodware Solutions
# Dallas, TX
# 5 hours ago
# Frontend Developer
# Frontend Developer
# Vimbly Group
# United States
# 6 days ago
# Frontend Developer
# Frontend Developer
# DataAnnotation
# United States
# 1 week ago
# Frontend Software Engineer
# Frontend Software Engineer
# Accelerant
# United States
# 1 month ago
# Frontend Developer
# Frontend Developer
# DataAnnotation
# Washington DC-Baltimore Area
# 1 week ago
# Similar Searches
# Web Integrator jobs
# 8,847 open jobs
# Web Development Specialist jobs
# 227,596 open jobs
# Senior Frontend Developer jobs
# 45,179 open jobs
# Web Developer jobs
# 39,398 open jobs
# Web Programmer jobs
# 4,657 open jobs
# Junior Web Developer jobs
# 8,869 open jobs
# HTML Developer jobs
# 10,363 open jobs
# Javascript Developer jobs
# 35,575 open jobs
# Back End Developer jobs
# 51,032 open jobs
# Developer Internship jobs
# 362 open jobs
# Developer jobs
# 258,935 open jobs
# Student Web Developer jobs
# 43 open jobs
# Wordpress Developer jobs
# 9,607 open jobs
# Layout Artist jobs
# 3,803 open jobs
# Junior Developer jobs
# 11,766 open jobs
# Web User Interface Developer jobs
# 13,302 open jobs
# Web Development Intern jobs
# 5,464 open jobs
# Computer Software Engineer jobs
# 224,521 open jobs
# Interface Programmer jobs
# 851 open jobs
# Information Programmer jobs
# 224,896 open jobs
# Freelance Web Developer jobs
# 22 open jobs
# Client Services Engineer jobs
# 226,659 open jobs
# Lead Web Developer jobs
# 41,977 open jobs
# User Interface Engineer jobs
# 223,207 open jobs
# Web Designer jobs
# 11,161 open jobs
# Show more
# Show less
# Explore collaborative articles
# We’re unlocking community knowledge in a new way. Experts add insights directly into each article, started with the help of AI.
# Explore More
# More searches
# More searches
# Web Integrator jobs
# Web Development Specialist jobs
# Senior Frontend Developer jobs
# Web Developer jobs
# Web Programmer jobs
# Junior Web Developer jobs
# HTML Developer jobs
# Javascript Developer jobs
# Back End Developer jobs
# Developer Internship jobs
# Lakeland Care jobs
# Developer jobs
# Student Web Developer jobs
# Wordpress Developer jobs
# Layout Artist jobs
# Junior Developer jobs
# Web User Interface Developer jobs
# Web Development Intern jobs
# Computer Software Engineer jobs
# Interface Programmer jobs
# Information Programmer jobs
# Freelance Web Developer jobs
# ROLINC Staffing & Search jobs
# Client Services Engineer jobs
# Lead Web Developer jobs
# User Interface Engineer jobs
# Web Designer jobs
# Web Application Developer jobs
# J2Ee Developer jobs
# Freelance Developer jobs
# Creative Developer jobs
# Software Engineer jobs
# Web Development Consultant jobs
# Junior Software Engineer jobs
# Webmaster jobs
# Front End Supervisor jobs
# Drupal Developer jobs
# Front End Architect jobs
# Idaho State University jobs
# Junior Java Developer jobs
# Ecommerce Developer jobs
# The Toledo Clinic jobs
# Full Stack Engineer jobs
# Web Design Intern jobs
# Web Content Developer jobs
# User Experience Engineer jobs
# PHP Developer jobs
# User Interface Specialist jobs
# Senior Web Developer jobs
# System Developer jobs
# Computer Software Specialist jobs
# Corporate Banking Officer jobs
# Junior Dotnet Developer jobs
# Media Developer jobs
# Multimedia Engineer jobs
# Web Application Programmer jobs
# Contract Web Developer jobs
# Interface Designer jobs
# Mobile Engineer jobs
# Game Developer jobs
# LinkedIn
# Know when new jobs open up
# Never miss a job alert with the new LinkedIn app for Windows.
# Get the app
# Sign in to see who you already know at Voltora Tech
# Sign in
# Welcome back
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# LinkedIn
# LinkedIn is better on the app
# Don’t have the app? Get it in the Microsoft Store.
# Open the app

# %%
job_system_prompt = (
    "You are a helpful assistant that analyzes job descriptions for software developers.\n"
    "Given a job description, extract:\n"
    "- A brief summary of the role\n"
    "- Required skills\n"
    "- Preferred (optional) skills\n"
    "- A list of matched and missing skills (based on user skills provided)\n"
    "- Resume bullet point suggestions\n"
    "- A short custom paragraph for a cover letter\n"
    "Respond in JSON format with those keys: summary, required_skills, preferred_skills, matched_skills, missing_skills, resume_bullets, cover_letter."
    
)

# %%
print(job_system_prompt)
# Out:
# You are a helpful assistant that analyzes job descriptions for software developers.
# Given a job description, extract:
# - A brief summary of the role
# - Required skills
# - Preferred (optional) skills
# - A list of matched and missing skills (based on user skills provided)
# - Resume bullet point suggestions
# - A short custom paragraph for a cover letter
# Respond in JSON format with those keys: summary, required_skills, preferred_skills, matched_skills, missing_skills, resume_bullets, cover_letter.

# %%
def get_job_user_prompt(job_description: str, user_skills: list[str]) -> str:
    skills_string = ", ".join(user_skills)
    return f"""Here is a job description:

{job_description}

The user's current skills are: {skills_string}

Please analyze the job post, extract the required and preferred skills, and compare with the user’s skills. Then generate a short resume bullet and a custom paragraph for a cover letter. Respond in JSON."""

# %%
job_description = """We are looking for a frontend developer with strong experience in React, TypeScript, and Tailwind CSS. Familiarity with REST APIs and CI/CD is a plus."""

user_skills = ["HTML", "CSS", "JavaScript", "Vue.js", "TypeScript"]

print(get_job_user_prompt(job_description,user_skills
))
# Out:
# Here is a job description:
#
# We are looking for a frontend developer with strong experience in React, TypeScript, and Tailwind CSS. Familiarity with REST APIs and CI/CD is a plus.
#
# The user's current skills are: HTML, CSS, JavaScript, Vue.js, TypeScript
#
# Please analyze the job post, extract the required and preferred skills, and compare with the user’s skills. Then generate a short resume bullet and a custom paragraph for a cover letter. Respond in JSON.

# %%
def analyze_job(job_description, user_skills):
    stream = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": job_system_prompt},
            {"role": "user", "content": get_job_user_prompt(job_description, user_skills)}
        ],
        stream=True
    )
    response = ""

    display_handle = display(Markdown(""), display_id=True) 
    
    for chunk in stream:
        content = chunk.choices[0].delta.content or ""
        response += content
        display_handle.update(Markdown(response))  

    return response

# %%
job_site = "https://www.linkedin.com/jobs/collections/recommended/?currentJobId=4172253511"
job_description = Website(job_site).text
user_skills = ["JavaScript", "React", "Tailwind", "Git", "TypeScript"]

result = analyze_job(job_description, user_skills)
# Out:
# ```json
# {
#   "summary": "The role involves developing high-quality web applications with a focus on user interface design, utilizing modern frameworks and tools.",
#   "required_skills": [
#     "JavaScript",
#     "React",
#     "HTML",
#     "CSS",
#     "Git",
#     "TypeScript"
#   ],
#   "preferred_skills": [
#     "Tailwind CSS",
#     "Redux",
#     "Node.js",
#     "Webpack",
#     "Testing frameworks (e.g., Jest, Mocha)"
#   ],
#   "matched_skills": [
#     "JavaScript",
#     "React",
#     "Git",
#     "TypeScript",
#     "Tailwind"
#   ],
#   "missing_skills": [
#     "HTML",
#     "CSS",
#     "Redux",
#     "Node.js",
#     "Webpack",
#     "Testing frameworks"
#   ],
#   "resume_bullets": [
#     "Developed responsive web applications using JavaScript and React, ensuring optimal user experiences.",
#     "Collaborated with UI/UX designers to implement designs using Tailwind CSS.",
#     "Utilized Git for version control in an Agile environment, managing feature branches and pull requests."
#   ],
#   "cover_letter": "I am excited to apply for the web developer position. With strong skills in JavaScript, React, and Tailwind CSS, I am passionate about creating user-friendly applications and have a track record of delivering high-quality code. I am eager to bring my expertise in modern web technologies to your team and contribute to innovative projects."
# }
# ```
